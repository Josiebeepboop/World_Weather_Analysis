# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-90.000,high=90.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]  
        city_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City":city.title(),
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max Temp":city_max_temp,
                          "Humidity":city_humidity,
                          "Cloudiness":city_clouds,
                          "Wind Speed":city_wind,
                          "Country":city_country,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | san cristobal
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | asfi
# Processing Record 5 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 1 | puerto colombia
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | pangnirtung
# Processing Record 11 of Set 1 | abu dhabi
# Processing Record 12 of Set 1 | raudeberg
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | oregon
# Processing Record 17 of Set 1 | forst
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 1 | padang
# Processing Record 21 of Set 1 | nadvirna
# Processing Record 22 of Set 1 | nieuwpoort
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | severodvinsk
# Processing Record 25 of Set 1 | touros
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | pitimbu
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | praia
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | sinazongwe
# Processing Record 32 of Set 1 | nuuk
# Processing Record 33 of Set 1 | amapa
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | vallenar
# Processing Record 37 of Set 1 | beloha
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | el doncello
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | usinsk
# Processing Record 44 of Set 1 | chateauroux
# Processing Record 45 of Set 1 | kaduna
# Processing Record 46 of Set 1 | sujawal
# City not found. Skipping...
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | kalabo
# Processing Record 50 of Set 1 | manono
# Processing Record 1 of Set 2 | grand gaube
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | puerto del rosario
# Processing Record 4 of Set 2 | tabou
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | neutraubling
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | bathsheba
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | camacha
# Processing Record 12 of Set 2 | torres
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | saint george
# Processing Record 15 of Set 2 | coulihaut
# City not found. Skipping...
# Processing Record 16 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 2 | cascais
# Processing Record 18 of Set 2 | caravelas
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | chimoio
# Processing Record 21 of Set 2 | bonfim
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | oriximina
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | nokaneng
# Processing Record 26 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 2 | kavaratti
# Processing Record 28 of Set 2 | kalomo
# City not found. Skipping...
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | altamira
# Processing Record 31 of Set 2 | georgiyevka
# Processing Record 32 of Set 2 | akdepe
# Processing Record 33 of Set 2 | arlit
# Processing Record 34 of Set 2 | narsaq
# Processing Record 35 of Set 2 | burica
# City not found. Skipping...
# Processing Record 36 of Set 2 | angelholm
# City not found. Skipping...
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | kudahuvadhoo
# Processing Record 40 of Set 2 | abha
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | sanford
# Processing Record 43 of Set 2 | mehamn
# Processing Record 44 of Set 2 | sabha
# Processing Record 45 of Set 2 | oum hadjer
# Processing Record 46 of Set 2 | mecca
# Processing Record 47 of Set 2 | cockburn town
# Processing Record 48 of Set 2 | kapuskasing
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | afzalgarh
# Processing Record 1 of Set 3 | gorele
# Processing Record 2 of Set 3 | souillac
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | moose factory
# Processing Record 9 of Set 3 | saint-joseph
# Processing Record 10 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 3 | cayenne
# Processing Record 12 of Set 3 | vila franca do campo
# Processing Record 13 of Set 3 | thinadhoo
# Processing Record 14 of Set 3 | bayir
# Processing Record 15 of Set 3 | korla
# Processing Record 16 of Set 3 | ahvaz
# Processing Record 17 of Set 3 | porto novo
# Processing Record 18 of Set 3 | cartagena
# Processing Record 19 of Set 3 | hornostayivka
# Processing Record 20 of Set 3 | bosaso
# Processing Record 21 of Set 3 | zhezkazgan
# Processing Record 22 of Set 3 | ostersund
# Processing Record 23 of Set 3 | yar-sale
# Processing Record 24 of Set 3 | saint anthony
# Processing Record 25 of Set 3 | berlevag
# Processing Record 26 of Set 3 | hofn
# Processing Record 27 of Set 3 | aswan
# Processing Record 28 of Set 3 | moville
# Processing Record 29 of Set 3 | mbandaka
# Processing Record 30 of Set 3 | sambava
# Processing Record 31 of Set 3 | vytegra
# Processing Record 32 of Set 3 | shache
# Processing Record 33 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | maniitsoq
# Processing Record 36 of Set 3 | harper
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | coihaique
# Processing Record 39 of Set 3 | laguna
# Processing Record 40 of Set 3 | porto nacional
# Processing Record 41 of Set 3 | sao miguel do araguaia
# Processing Record 42 of Set 3 | fortaleza
# Processing Record 43 of Set 3 | maceio
# Processing Record 44 of Set 3 | kalemie
# Processing Record 45 of Set 3 | lagoa
# Processing Record 46 of Set 3 | isabela
# Processing Record 47 of Set 3 | xirokambos
# City not found. Skipping...
# Processing Record 48 of Set 3 | fuerte olimpo
# Processing Record 49 of Set 3 | muhos
# Processing Record 50 of Set 3 | sajanan
# Processing Record 1 of Set 4 | nouadhibou
# Processing Record 2 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 4 | rio grande
# Processing Record 4 of Set 4 | yenagoa
# Processing Record 5 of Set 4 | varnamo
# Processing Record 6 of Set 4 | kinsale
# Processing Record 7 of Set 4 | dingle
# Processing Record 8 of Set 4 | governador valadares
# Processing Record 9 of Set 4 | eatonton
# Processing Record 10 of Set 4 | derzhavinsk
# Processing Record 11 of Set 4 | cajica
# Processing Record 12 of Set 4 | mbaiki
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | solwezi
# Processing Record 15 of Set 4 | abaete
# Processing Record 16 of Set 4 | bay roberts
# Processing Record 17 of Set 4 | sile
# Processing Record 18 of Set 4 | gijon
# Processing Record 19 of Set 4 | pastavy
# Processing Record 20 of Set 4 | chapais
# Processing Record 21 of Set 4 | knysna
# Processing Record 22 of Set 4 | namibe
# Processing Record 23 of Set 4 | bila tserkva
# Processing Record 24 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 4 | mitu
# Processing Record 26 of Set 4 | rakai
# Processing Record 27 of Set 4 | ostrovnoy
# Processing Record 28 of Set 4 | pangody
# Processing Record 29 of Set 4 | arroio grande
# Processing Record 30 of Set 4 | ovalle
# Processing Record 31 of Set 4 | acri
# Processing Record 32 of Set 4 | izmit
# Processing Record 33 of Set 4 | krasnoselkup
# Processing Record 34 of Set 4 | sao gabriel da cachoeira
# Processing Record 35 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 4 | vigia
# Processing Record 37 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 38 of Set 4 | inhambane
# Processing Record 39 of Set 4 | inirida
# Processing Record 40 of Set 4 | eshowe
# Processing Record 41 of Set 4 | yabelo
# Processing Record 42 of Set 4 | melilla
# Processing Record 43 of Set 4 | cabedelo
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | wicklow
# Processing Record 46 of Set 4 | ouadda
# Processing Record 47 of Set 4 | henties bay
# Processing Record 48 of Set 4 | suleja
# Processing Record 49 of Set 4 | kita
# Processing Record 50 of Set 4 | vestmannaeyjar
# Processing Record 1 of Set 5 | awbari
# Processing Record 2 of Set 5 | uvat
# Processing Record 3 of Set 5 | kattivakkam
# Processing Record 4 of Set 5 | comodoro rivadavia
# Processing Record 5 of Set 5 | khomeyn
# Processing Record 6 of Set 5 | grindavik
# Processing Record 7 of Set 5 | presidente epitacio
# Processing Record 8 of Set 5 | oron
# Processing Record 9 of Set 5 | jalu
# Processing Record 10 of Set 5 | port-gentil
# Processing Record 11 of Set 5 | valparaiso
# Processing Record 12 of Set 5 | lere
# Processing Record 13 of Set 5 | hazorasp
# Processing Record 14 of Set 5 | galbshtadt
# Processing Record 15 of Set 5 | oeiras do para
# Processing Record 16 of Set 5 | zuwarah
# Processing Record 17 of Set 5 | longyearbyen
# Processing Record 18 of Set 5 | sao caetano de odivelas
# Processing Record 19 of Set 5 | ji-parana
# City not found. Skipping...
# Processing Record 20 of Set 5 | lucenec
# Processing Record 21 of Set 5 | ypsilanti
# Processing Record 22 of Set 5 | neath
# Processing Record 23 of Set 5 | goderich
# Processing Record 24 of Set 5 | lozuvatka
# Processing Record 25 of Set 5 | krasnyy kut
# Processing Record 26 of Set 5 | zavodouspenskoye
# Processing Record 27 of Set 5 | tarrafal
# Processing Record 28 of Set 5 | sinnamary
# Processing Record 29 of Set 5 | belmonte
# Processing Record 30 of Set 5 | quatre cocos
# Processing Record 31 of Set 5 | riyadh
# Processing Record 32 of Set 5 | masunga
# Processing Record 33 of Set 5 | san rafael
# Processing Record 34 of Set 5 | muzaffargarh
# Processing Record 35 of Set 5 | cayce
# Processing Record 36 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 5 | brokopondo
# Processing Record 38 of Set 5 | requena
# Processing Record 39 of Set 5 | plettenberg bay
# Processing Record 40 of Set 5 | loandjili
# Processing Record 41 of Set 5 | bonthe
# Processing Record 42 of Set 5 | chicama
# Processing Record 43 of Set 5 | mwense
# Processing Record 44 of Set 5 | point pedro
# Processing Record 45 of Set 5 | sorland
# Processing Record 46 of Set 5 | saint-ambroise
# Processing Record 47 of Set 5 | ust-tsilma
# Processing Record 48 of Set 5 | bubaque
# Processing Record 49 of Set 5 | hukuntsi
# Processing Record 50 of Set 5 | hindoria
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | bandarbeyla
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | betsiamites
# Processing Record 5 of Set 6 | soyo
# Processing Record 6 of Set 6 | beaver dam
# Processing Record 7 of Set 6 | mayor pablo lagerenza
# Processing Record 8 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | chiman
# Processing Record 11 of Set 6 | takoradi
# Processing Record 12 of Set 6 | puerto carreno
# Processing Record 13 of Set 6 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 14 of Set 6 | saint-pierre
# Processing Record 15 of Set 6 | luderitz
# Processing Record 16 of Set 6 | kentau
# Processing Record 17 of Set 6 | termoli
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | jaciara
# Processing Record 20 of Set 6 | salreu
# Processing Record 21 of Set 6 | sebeta
# Processing Record 22 of Set 6 | khandbari
# Processing Record 23 of Set 6 | bjornevatn
# Processing Record 24 of Set 6 | kruisfontein
# Processing Record 25 of Set 6 | skelleftea
# Processing Record 26 of Set 6 | pudozh
# Processing Record 27 of Set 6 | kangasala
# Processing Record 28 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 6 | hansi
# Processing Record 30 of Set 6 | kohlu
# Processing Record 31 of Set 6 | agliana
# Processing Record 32 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 33 of Set 6 | marystown
# Processing Record 34 of Set 6 | maragogi
# Processing Record 35 of Set 6 | hualmay
# Processing Record 36 of Set 6 | carballo
# Processing Record 37 of Set 6 | boa vista
# Processing Record 38 of Set 6 | saint-augustin
# Processing Record 39 of Set 6 | peniche
# Processing Record 40 of Set 6 | shemonaikha
# Processing Record 41 of Set 6 | farah
# Processing Record 42 of Set 6 | olinda
# Processing Record 43 of Set 6 | campestre
# Processing Record 44 of Set 6 | salalah
# Processing Record 45 of Set 6 | umm kaddadah
# Processing Record 46 of Set 6 | vadso
# Processing Record 47 of Set 6 | sur
# Processing Record 48 of Set 6 | lappeenranta
# Processing Record 49 of Set 6 | olafsvik
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | moultrie
# Processing Record 2 of Set 7 | muros
# Processing Record 3 of Set 7 | yarmouth
# Processing Record 4 of Set 7 | porto torres
# Processing Record 5 of Set 7 | linden
# Processing Record 6 of Set 7 | naryan-mar
# Processing Record 7 of Set 7 | san ramon de la nueva oran
# Processing Record 8 of Set 7 | guanica
# Processing Record 9 of Set 7 | santa maria
# Processing Record 10 of Set 7 | tandil
# Processing Record 11 of Set 7 | pasni
# Processing Record 12 of Set 7 | ghanzi
# Processing Record 13 of Set 7 | kidal
# Processing Record 14 of Set 7 | chibombo
# Processing Record 15 of Set 7 | stornoway
# Processing Record 16 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 17 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 7 | hilton head island
# Processing Record 19 of Set 7 | alta floresta
# Processing Record 20 of Set 7 | chimbote
# Processing Record 21 of Set 7 | itarema
# Processing Record 22 of Set 7 | sao paulo de olivenca
# Processing Record 23 of Set 7 | tucupita
# Processing Record 24 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 25 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 7 | san roque
# Processing Record 27 of Set 7 | donskoy
# Processing Record 28 of Set 7 | general roca
# Processing Record 29 of Set 7 | gayny
# Processing Record 30 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 7 | narayanpet
# Processing Record 32 of Set 7 | barga
# Processing Record 33 of Set 7 | veraval
# Processing Record 34 of Set 7 | puerto leguizamo
# Processing Record 35 of Set 7 | kyabe
# Processing Record 36 of Set 7 | labrea
# Processing Record 37 of Set 7 | braunau
# Processing Record 38 of Set 7 | vigrestad
# Processing Record 39 of Set 7 | trelew
# Processing Record 40 of Set 7 | kontagora
# Processing Record 41 of Set 7 | iberia
# Processing Record 42 of Set 7 | llandrindod wells
# Processing Record 43 of Set 7 | artyom
# Processing Record 44 of Set 7 | dudinka
# Processing Record 45 of Set 7 | dubno
# Processing Record 46 of Set 7 | kluczbork
# Processing Record 47 of Set 7 | adrar
# Processing Record 48 of Set 7 | ngaoundere
# Processing Record 49 of Set 7 | gambo
# Processing Record 50 of Set 7 | guaruja
# Processing Record 1 of Set 8 | amos
# Processing Record 2 of Set 8 | aksarka
# Processing Record 3 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 4 of Set 8 | hambantota
# Processing Record 5 of Set 8 | isiro
# Processing Record 6 of Set 8 | penzance
# Processing Record 7 of Set 8 | luanda
# Processing Record 8 of Set 8 | koygorodok
# Processing Record 9 of Set 8 | mehriz
# Processing Record 10 of Set 8 | bengkulu
# Processing Record 11 of Set 8 | jumla
# Processing Record 12 of Set 8 | lahij
# Processing Record 13 of Set 8 | kisangani
# Processing Record 14 of Set 8 | alferrarede
# Processing Record 15 of Set 8 | paonta sahib
# Processing Record 16 of Set 8 | carbondale
# Processing Record 17 of Set 8 | thaba-tseka
# Processing Record 18 of Set 8 | akhtubinsk
# Processing Record 19 of Set 8 | hattiesburg
# Processing Record 20 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 21 of Set 8 | rundu
# Processing Record 22 of Set 8 | owando
# Processing Record 23 of Set 8 | trincomalee
# Processing Record 24 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 25 of Set 8 | tramore
# Processing Record 26 of Set 8 | salinopolis
# Processing Record 27 of Set 8 | sechura
# Processing Record 28 of Set 8 | grantham
# Processing Record 29 of Set 8 | rondonopolis
# Processing Record 30 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 8 | presidencia roque saenz pena
# Processing Record 32 of Set 8 | mvuma
# Processing Record 33 of Set 8 | santiago del estero
# Processing Record 34 of Set 8 | qrendi
# Processing Record 35 of Set 8 | astana
# Processing Record 36 of Set 8 | tutoia
# Processing Record 37 of Set 8 | tahoua
# Processing Record 38 of Set 8 | vestmanna
# Processing Record 39 of Set 8 | port blair
# Processing Record 40 of Set 8 | matara
# Processing Record 41 of Set 8 | bangolo
# Processing Record 42 of Set 8 | birjand
# Processing Record 43 of Set 8 | pafos
# Processing Record 44 of Set 8 | pokhara
# Processing Record 45 of Set 8 | nkhata bay
# Processing Record 46 of Set 8 | sindgi
# Processing Record 47 of Set 8 | kumbo
# Processing Record 48 of Set 8 | nantucket
# Processing Record 49 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 50 of Set 8 | tocache
# Processing Record 1 of Set 9 | pathardi
# Processing Record 2 of Set 9 | merke
# Processing Record 3 of Set 9 | albany
# Processing Record 4 of Set 9 | handwara
# City not found. Skipping...
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 9 | am timan
# Processing Record 8 of Set 9 | arona
# Processing Record 9 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 9 | sao joao da barra
# Processing Record 11 of Set 9 | geraldton
# Processing Record 12 of Set 9 | gemena
# Processing Record 13 of Set 9 | volodarskiy
# Processing Record 14 of Set 9 | augusto correa
# Processing Record 15 of Set 9 | port hawkesbury
# Processing Record 16 of Set 9 | chiknayakanhalli
# Processing Record 17 of Set 9 | kismayo
# Processing Record 18 of Set 9 | lugovoy
# Processing Record 19 of Set 9 | ilhabela
# Processing Record 20 of Set 9 | rodrigues alves
# Processing Record 21 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 9 | mushie
# Processing Record 23 of Set 9 | tigzirt
# Processing Record 24 of Set 9 | itinga
# Processing Record 25 of Set 9 | mazyr
# Processing Record 26 of Set 9 | tarpon springs
# Processing Record 27 of Set 9 | makushino
# Processing Record 28 of Set 9 | la asuncion
# Processing Record 29 of Set 9 | rawson
# Processing Record 30 of Set 9 | buchanan
# Processing Record 31 of Set 9 | huarmey
# Processing Record 32 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 33 of Set 9 | carnarvon
# Processing Record 34 of Set 9 | seidu
# Processing Record 35 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 9 | najran
# Processing Record 37 of Set 9 | tazovskiy
# Processing Record 38 of Set 9 | jutai
# Processing Record 39 of Set 9 | bolobo
# Processing Record 40 of Set 9 | marawi
# Processing Record 41 of Set 9 | maltahohe
# Processing Record 42 of Set 9 | mana
# Processing Record 43 of Set 9 | ambilobe
# Processing Record 44 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 45 of Set 9 | ouango
# Processing Record 46 of Set 9 | matsanga
# City not found. Skipping...
# Processing Record 47 of Set 9 | goure
# Processing Record 48 of Set 9 | porto de moz
# Processing Record 49 of Set 9 | bushehr
# Processing Record 50 of Set 9 | inta
# Processing Record 1 of Set 10 | saint-georges
# Processing Record 2 of Set 10 | okhtyrka
# Processing Record 3 of Set 10 | puri
# Processing Record 4 of Set 10 | taltal
# Processing Record 5 of Set 10 | englewood
# Processing Record 6 of Set 10 | sault sainte marie
# Processing Record 7 of Set 10 | grand-lahou
# Processing Record 8 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 10 of Set 10 | las palmas
# Processing Record 11 of Set 10 | sven
# Processing Record 12 of Set 10 | almirante
# Processing Record 13 of Set 10 | bonavista
# Processing Record 14 of Set 10 | richards bay
# Processing Record 15 of Set 10 | santa cruz
# Processing Record 16 of Set 10 | domaszek
# Processing Record 17 of Set 10 | rajura
# Processing Record 18 of Set 10 | westerland
# Processing Record 19 of Set 10 | gamba
# Processing Record 20 of Set 10 | barcelos
# Processing Record 21 of Set 10 | lamu
# Processing Record 22 of Set 10 | collierville
# Processing Record 23 of Set 10 | westport
# Processing Record 24 of Set 10 | nokha
# Processing Record 25 of Set 10 | yagoua
# Processing Record 26 of Set 10 | san luis
# Processing Record 27 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 10 | jacareacanga
# Processing Record 29 of Set 10 | atar
# Processing Record 30 of Set 10 | coquimbo
# Processing Record 31 of Set 10 | lake station
# Processing Record 32 of Set 10 | quattro castella
# Processing Record 33 of Set 10 | bud
# Processing Record 34 of Set 10 | harbour breton
# Processing Record 35 of Set 10 | aripuana
# Processing Record 36 of Set 10 | matadi
# Processing Record 37 of Set 10 | timizart
# Processing Record 38 of Set 10 | odweyne
# Processing Record 39 of Set 10 | nador
# Processing Record 40 of Set 10 | novoagansk
# Processing Record 41 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 10 | nosy varika
# Processing Record 43 of Set 10 | conde
# Processing Record 44 of Set 10 | rzeszow
# Processing Record 45 of Set 10 | halifax
# Processing Record 46 of Set 10 | gravdal
# Processing Record 47 of Set 10 | ptichye
# Processing Record 48 of Set 10 | sucre
# Processing Record 49 of Set 10 | havoysund
# Processing Record 50 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 1 of Set 11 | knokke-heist
# Processing Record 2 of Set 11 | antofagasta
# Processing Record 3 of Set 11 | resistencia
# Processing Record 4 of Set 11 | mabaruma
# Processing Record 5 of Set 11 | kang
# Processing Record 6 of Set 11 | ponta delgada
# Processing Record 7 of Set 11 | gravina in puglia
# Processing Record 8 of Set 11 | vittorio veneto
# Processing Record 9 of Set 11 | margate
# Processing Record 10 of Set 11 | ikovka
# Processing Record 11 of Set 11 | saquarema
# Processing Record 12 of Set 11 | mendeleyevo
# Processing Record 13 of Set 11 | teguldet
# Processing Record 14 of Set 11 | ayagoz
# Processing Record 15 of Set 11 | high rock
# Processing Record 16 of Set 11 | taoudenni
# Processing Record 17 of Set 11 | poole
# Processing Record 18 of Set 11 | hurghada
# Processing Record 19 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 20 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 11 | eenhana
# Processing Record 22 of Set 11 | gore
# Processing Record 23 of Set 11 | pimentel
# Processing Record 24 of Set 11 | youghal
# Processing Record 25 of Set 11 | svolvaer
# Processing Record 26 of Set 11 | terbuny
# Processing Record 27 of Set 11 | mauganj
# Processing Record 28 of Set 11 | ekibastuz
# Processing Record 29 of Set 11 | koungheul
# Processing Record 30 of Set 11 | bloomingdale
# Processing Record 31 of Set 11 | gumia
# Processing Record 32 of Set 11 | barreiras
# Processing Record 33 of Set 11 | soubre
# Processing Record 34 of Set 11 | faya
# Processing Record 35 of Set 11 | calderitas
# Processing Record 36 of Set 11 | dothan
# Processing Record 37 of Set 11 | miranda
# Processing Record 38 of Set 11 | skjervoy
# Processing Record 39 of Set 11 | lenoir city
# Processing Record 40 of Set 11 | carsamba
# Processing Record 41 of Set 11 | buraydah
# Processing Record 42 of Set 11 | avanigadda
# Processing Record 43 of Set 11 | gusau
# Processing Record 44 of Set 11 | perry
# Processing Record 45 of Set 11 | kandalaksha
# Processing Record 46 of Set 11 | challans
# Processing Record 47 of Set 11 | evora
# Processing Record 48 of Set 11 | savannah bight
# Processing Record 49 of Set 11 | bagepalli
# Processing Record 50 of Set 11 | spetsai
# City not found. Skipping...
# Processing Record 1 of Set 12 | kholmogory
# Processing Record 2 of Set 12 | russkiy kameshkir
# Processing Record 3 of Set 12 | pontes e lacerda
# Processing Record 4 of Set 12 | alta gracia
# Processing Record 5 of Set 12 | somerset
# Processing Record 6 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 12 | caxito
# Processing Record 8 of Set 12 | gazanjyk
# Processing Record 9 of Set 12 | kiruna
# Processing Record 10 of Set 12 | stavern
# Processing Record 11 of Set 12 | tessalit
# Processing Record 12 of Set 12 | honningsvag
# Processing Record 13 of Set 12 | lichinga
# Processing Record 14 of Set 12 | sfantu gheorghe
# Processing Record 15 of Set 12 | brae
# Processing Record 16 of Set 12 | robertsport
# Processing Record 17 of Set 12 | ampanihy
# Processing Record 18 of Set 12 | piacabucu
# Processing Record 19 of Set 12 | constantine
# Processing Record 20 of Set 12 | bunia
# Processing Record 21 of Set 12 | los llanos de aridane
# Processing Record 22 of Set 12 | sistranda
# Processing Record 23 of Set 12 | dezful
# Processing Record 24 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 25 of Set 12 | damaturu
# Processing Record 26 of Set 12 | west bay
# Processing Record 27 of Set 12 | ginda
# Processing Record 28 of Set 12 | havre-saint-pierre
# Processing Record 29 of Set 12 | okitipupa
# Processing Record 30 of Set 12 | angra
# City not found. Skipping...
# Processing Record 31 of Set 12 | pervomaysk
# Processing Record 32 of Set 12 | mazagao
# Processing Record 33 of Set 12 | mumbwa
# Processing Record 34 of Set 12 | karachi
# Processing Record 35 of Set 12 | balkhash
# Processing Record 36 of Set 12 | hammerfest
# Processing Record 37 of Set 12 | morondava
# Processing Record 38 of Set 12 | lavumisa
# Processing Record 39 of Set 12 | buritis
# Processing Record 40 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 12 | darab
# Processing Record 42 of Set 12 | cap malheureux
# Processing Record 43 of Set 12 | ardalstangen
# Processing Record 44 of Set 12 | pedernales
# Processing Record 45 of Set 12 | nexo
# Processing Record 46 of Set 12 | otjiwarongo
# Processing Record 47 of Set 12 | springbok
# Processing Record 48 of Set 12 | zinder
# Processing Record 49 of Set 12 | krasnyy yar
# Processing Record 50 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 1 of Set 13 | carutapera
# Processing Record 2 of Set 13 | farafangana
# Processing Record 3 of Set 13 | leczna
# Processing Record 4 of Set 13 | birin
# Processing Record 5 of Set 13 | lima
# Processing Record 6 of Set 13 | tromso
# Processing Record 7 of Set 13 | polunochnoye
# Processing Record 8 of Set 13 | saint-denis
# Processing Record 9 of Set 13 | nepa nagar
# Processing Record 10 of Set 13 | faro
# Processing Record 11 of Set 13 | praia da vitoria
# Processing Record 12 of Set 13 | hamza
# Processing Record 13 of Set 13 | barra do garcas
# Processing Record 14 of Set 13 | carlisle
# Processing Record 15 of Set 13 | gilgit
# Processing Record 16 of Set 13 | lyubech
# Processing Record 17 of Set 13 | aden
# Processing Record 18 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 13 | namanyere
# Processing Record 20 of Set 13 | palmeirais
# Processing Record 21 of Set 13 | linares
# Processing Record 22 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 23 of Set 13 | nicoya
# Processing Record 24 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 25 of Set 13 | marovoay
# Processing Record 26 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 27 of Set 13 | zavetnoye
# Processing Record 28 of Set 13 | shubarshi
# Processing Record 29 of Set 13 | belyy yar
# Processing Record 30 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 31 of Set 13 | zaraza
# Processing Record 32 of Set 13 | araouane
# Processing Record 33 of Set 13 | sao felix do xingu
# Processing Record 34 of Set 13 | mantua
# Processing Record 35 of Set 13 | lleida
# Processing Record 36 of Set 13 | linhares
# Processing Record 37 of Set 13 | nizhnevartovsk
# Processing Record 38 of Set 13 | san ramon
# Processing Record 39 of Set 13 | ivdel
# Processing Record 40 of Set 13 | mapiripan
# Processing Record 41 of Set 13 | staunton
# Processing Record 42 of Set 13 | wagar
# Processing Record 43 of Set 13 | vorobyevka
# Processing Record 44 of Set 13 | altay
# Processing Record 45 of Set 13 | opuwo
# Processing Record 46 of Set 13 | dilla
# Processing Record 47 of Set 13 | conakry
# Processing Record 48 of Set 13 | kitovo
# Processing Record 49 of Set 13 | mimongo
# Processing Record 50 of Set 13 | yangambi
# Processing Record 1 of Set 14 | manyana
# Processing Record 2 of Set 14 | amboasary
# Processing Record 3 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 14 | abalak
# Processing Record 5 of Set 14 | channel-port aux basques
# Processing Record 6 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 14 | covington
# Processing Record 8 of Set 14 | tudora
# Processing Record 9 of Set 14 | nisia floresta
# Processing Record 10 of Set 14 | isla mujeres
# Processing Record 11 of Set 14 | ladnun
# Processing Record 12 of Set 14 | sivagiri
# Processing Record 13 of Set 14 | tera
# Processing Record 14 of Set 14 | krasnovishersk
# Processing Record 15 of Set 14 | elat
# Processing Record 16 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 17 of Set 14 | bakchar
# Processing Record 18 of Set 14 | catamarca
# Processing Record 19 of Set 14 | nouakchott
# Processing Record 20 of Set 14 | trairi
# Processing Record 21 of Set 14 | angoche
# Processing Record 22 of Set 14 | corn island
# Processing Record 23 of Set 14 | huanta
# Processing Record 24 of Set 14 | nioro
# Processing Record 25 of Set 14 | himora
# City not found. Skipping...
# Processing Record 26 of Set 14 | gweru
# Processing Record 27 of Set 14 | parana
# Processing Record 28 of Set 14 | hobyo
# Processing Record 29 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 30 of Set 14 | necochea
# Processing Record 31 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 32 of Set 14 | hluti
# Processing Record 33 of Set 14 | qaqortoq
# Processing Record 34 of Set 14 | willowmore
# Processing Record 35 of Set 14 | souris
# Processing Record 36 of Set 14 | maroantsetra
# Processing Record 37 of Set 14 | magole
# Processing Record 38 of Set 14 | novogurovskiy
# Processing Record 39 of Set 14 | fort-shevchenko
# Processing Record 40 of Set 14 | sindor
# Processing Record 41 of Set 14 | cotonou
# Processing Record 42 of Set 14 | maloyaz
# City not found. Skipping...
# Processing Record 43 of Set 14 | chhindwara
# Processing Record 44 of Set 14 | karlskoga
# Processing Record 45 of Set 14 | lar gerd
# City not found. Skipping...
# Processing Record 46 of Set 14 | iracoubo
# Processing Record 47 of Set 14 | svetlyy
# Processing Record 48 of Set 14 | nikki
# Processing Record 49 of Set 14 | golynki
# Processing Record 50 of Set 14 | baiao
# Processing Record 1 of Set 15 | kozhevnikovo
# Processing Record 2 of Set 15 | grand-santi
# Processing Record 3 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 4 of Set 15 | zlobin
# Processing Record 5 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 15 | san matias
# Processing Record 7 of Set 15 | chany
# Processing Record 8 of Set 15 | oume
# Processing Record 9 of Set 15 | talas
# Processing Record 10 of Set 15 | baft
# Processing Record 11 of Set 15 | dwarka
# Processing Record 12 of Set 15 | guanare
# Processing Record 13 of Set 15 | kakonko
# Processing Record 14 of Set 15 | upington
# Processing Record 15 of Set 15 | vagur
# Processing Record 16 of Set 15 | camapua
# Processing Record 17 of Set 15 | menongue
# Processing Record 18 of Set 15 | conceicao do araguaia
# Processing Record 19 of Set 15 | kalininsk
# Processing Record 20 of Set 15 | santa cruz de la palma
# Processing Record 21 of Set 15 | signagi
# City not found. Skipping...
# Processing Record 22 of Set 15 | malinovka
# Processing Record 23 of Set 15 | ngorongoro
# Processing Record 24 of Set 15 | prieska
# Processing Record 25 of Set 15 | kumluca
# Processing Record 26 of Set 15 | siguiri
# Processing Record 27 of Set 15 | virginia beach
# Processing Record 28 of Set 15 | tadpatri
# Processing Record 29 of Set 15 | botwood
# Processing Record 30 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 15 | kadoma
# Processing Record 32 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 15 | eten
# Processing Record 34 of Set 15 | storforshei
# Processing Record 35 of Set 15 | moron de la frontera
# Processing Record 36 of Set 15 | valdivia
# Processing Record 37 of Set 15 | grasse
# Processing Record 38 of Set 15 | bernal
# Processing Record 39 of Set 15 | bereda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 663

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cape Town -33.9258   18.4232     15.49        81           0
# 1    San Cristobal   7.7669  -72.2250     26.10        48          89
# 2             Asfi  32.2994   -9.2372     21.86        76           0
# 3       Codrington -38.2667  141.9667      7.66        89         100
# 4  Puerto Colombia  10.9878  -74.9547     31.05        72          39
# 5          Ushuaia -54.8000  -68.3000      9.81        40           0
# 6      Pangnirtung  66.1451  -65.7125      0.45        51           0
# 7        Abu Dhabi  24.4667   54.3667     31.01        73           0
# 8        Raudeberg  61.9875    5.1352     11.37         1          38
# 9       Bredasdorp -34.5322   20.0403     11.96        91           3
#
#    Wind Speed Country Current Description
# 0        3.09      ZA           clear sky
# 1        3.29      VE     overcast clouds
# 2        1.50      MA           clear sky
# 3        1.92      AU     overcast clouds
# 4        5.94      CO    scattered clouds
# 5        1.54      AR           clear sky
# 6        2.42      CA           clear sky
# 7        2.06      AE           clear sky
# 8        8.45      NO    scattered clouds
# 9        2.59      ZA           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cape Town      ZA -33.9258   18.4232     15.49        81           0
# 1    San Cristobal      VE   7.7669  -72.2250     26.10        48          89
# 2             Asfi      MA  32.2994   -9.2372     21.86        76           0
# 3       Codrington      AU -38.2667  141.9667      7.66        89         100
# 4  Puerto Colombia      CO  10.9878  -74.9547     31.05        72          39
# 5          Ushuaia      AR -54.8000  -68.3000      9.81        40           0
# 6      Pangnirtung      CA  66.1451  -65.7125      0.45        51           0
# 7        Abu Dhabi      AE  24.4667   54.3667     31.01        73           0
# 8        Raudeberg      NO  61.9875    5.1352     11.37         1          38
# 9       Bredasdorp      ZA -34.5322   20.0403     11.96        91           3
#
#    Wind Speed Current Description
# 0        3.09           clear sky
# 1        3.29     overcast clouds
# 2        1.50           clear sky
# 3        1.92     overcast clouds
# 4        5.94    scattered clouds
# 5        1.54           clear sky
# 6        2.42           clear sky
# 7        2.06           clear sky
# 8        8.45    scattered clouds
# 9        2.59           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file='WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label='City_ID')
